# %% [markdown]
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/juliopez/Mineria-Datos/blob/main/notebooks/Proyecto_Integrador-Avance_1.ipynb)
# # Proyecto Integrador- Avance 1
#
# **Dataset:** `Clientes Retail Omnicanal.csv`
#
# **Objetivo:** Explorar el dataset, identificar variables, detectar problemas de calidad y generar primeros insights.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Cargar datos

# %%
df = pd.read_csv('clientes_retail_omnicanal.csv')
df.head()

# %% [markdown]
# ## Información general del dataset

# %%
df.info()
df.describe()

# %% [markdown]
# ## Identificación de variables

# %%
df.dtypes

# %% [markdown]
# ## Detección de valores nulos

# %%
df.isnull().sum()

# %% [markdown]
# ## Detección de duplicados

# %%
df.duplicated().sum()

# %% [markdown]
# ## Análisis exploratorio EDA (ejemplo)

# %%
df['monto_total'].hist()
plt.title('Distribución monto total')
plt.show()

# %% [markdown]
# ## Limpieza de datos (ejemplo)

# %%
# eliminar duplicados
df = df.drop_duplicates()

# %% [markdown]
# ## 💡 Insights
# Escribe aquí tus principales hallazgos.
